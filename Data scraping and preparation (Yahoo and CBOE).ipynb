# %%
from bs4 import BeautifulSoup
import requests
from tqdm import tqdm 
import pandas as pd
from yahoo_fin.stock_info import get_data

# %% [markdown]
# ## Scrape data from Yahoo

# %%
dfY = get_data('^VIX')['2014-01-02':'2021-09-20']
dfY.drop(['open', 'high', 'low', 'close', 'volume', 'ticker'],1,inplace=True)
dfY.reset_index(inplace = True)
dfY.columns = ['Trade Date', 'VIX']

dfY.head()
# Out:
#   Trade Date    VIX
# 0 2014-01-02  14.23
# 1 2014-01-03  13.76
# 2 2014-01-06  13.55
# 3 2014-01-07  12.92
# 4 2014-01-08  12.87

# %% [markdown]
# ## Scrape data from CBOE

# %%
page=requests.get('https://www.cboe.com/us/futures/market_statistics/historical_data/')
soup = BeautifulSoup(page.text, 'html.parser')

dfs = soup.findAll('li', {'class':'mbn'})
# Out:
# 366

# %%
dicMonths = {'F':1,'G':2,'H':3,'J':4,'K':5,'M':6,'N':7,'Q':8,'U':9,'V':10,'X':11,'Z':12}
dicYears = {'2':2022, '1':2021, '0':2020, '9':2019, '8':2018, '7':2017, '6':2016, '5':2015, '4':2014, '3':2013}

#sort the names of dataframes by year and month
dff = [df.a.text.strip().split()[1] for df in dfs[::-1]]
sorted_dff = sorted(dff, key= lambda xy:(dicYears[xy[1]], dicMonths[xy[0]]))

#get the indexes of sorted dataframes
idx = [dff.index(elt) for elt in sorted_dff]

#get the sorted dataframes
dfs = dfs[::-1]
dfs = [dfs[i] for i in idx]

# %%
# remove dfs of the year 2013 and the weekly ones VX + VXT01 ...
dfs = [df for df in dfs if not df.a.text.split('+')[1][3:5].isnumeric() and df.a['href'].split('/')[3].split('-')[0] != '2013']
len(dfs)
# Out:
# 102

# %%
newdata = pd.DataFrame(columns = ['Futures', 'Settle'])

# scrape the link of dfs then join it 
for df in dfs :
    
        link = df.a['href']
        data = pd.read_csv('https://www.cboe.com/us/futures/market_statistics/historical_data/'+ link)
        data.set_index('Trade Date', inplace = True)
        if len(newdata) == 0 :
            newdata = data[['Futures', 'Settle']]
            last = newdata.index[-1]
           
        else :
            newdata = pd.concat([newdata[:-1], data.loc[last:,['Futures', 'Settle']]])
            last = newdata.index[-1]

# %%
save = newdata
newdata.sample(5)
# Out:
#                  Futures  Settle
# Trade Date
# 2019-12-04  Z (Dec 2019)  15.325
# 2020-04-30  K (May 2020)  33.975
# 2014-11-17  X (Nov 2014)  14.350
# 2019-08-29  U (Sep 2019)  18.475
# 2020-07-27  Q (Aug 2020)  27.525

# %% [markdown]
# ## Data Preparation

# %%
feat = ['feature 1', 'feature 2', 'feature 3', 'feature 4', 'feature 5', 'feature 6', 'feature 7', 'feature 8', 'feature 9', 'feature 10']
data = pd.DataFrame(columns = feat)
data
# Out:
# Empty DataFrame
# Columns: [feature 1, feature 2, feature 3, feature 4, feature 5, feature 6, feature 7, feature 8, feature 9, feature 10]
# Index: []

# %%
newdata = newdata.reset_index()
newdata.head(2)
# Out:
#    Trade Date       Futures  Settle
# 0  2013-04-22  F (Jan 2014)     0.0
# 1  2013-04-23  F (Jan 2014)     0.0

# %%
newdata['Trade Date'] = pd.to_datetime(newdata['Trade Date'],errors='ignore')

# %%
new = newdata.join(dfY.set_index('Trade Date'), on='Trade Date')
new = pd.concat([new, data])

new = new[new['VIX'].notna()]
new=new.sort_values(ascending = False, by='Trade Date')

new.head()
# Out:
#      Trade Date       Futures   Settle        VIX feature 1 feature 2  \
# 2121 2021-09-20  V (Oct 2021)  24.4629  25.709999       NaN       NaN
# 2120 2021-09-17  V (Oct 2021)  21.9377  20.809999       NaN       NaN
# 2119 2021-09-16  V (Oct 2021)  20.5556  18.690001       NaN       NaN
# 2118 2021-09-15  V (Oct 2021)  20.8379  18.180000       NaN       NaN
# 2117 2021-09-14  U (Sep 2021)  19.7150  19.459999       NaN       NaN
#
#      feature 3 feature 4 feature 5 feature 6 feature 7 feature 8 feature 9  \
# 2121       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2120       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2119       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2118       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2117       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#      feature 10
# 2121        NaN
# 2120        NaN
# 2119        NaN
# 2118        NaN
# 2117        NaN

# %%
new.set_index('Trade Date', inplace = True)
new.head()
# Out:
#                  Futures   Settle        VIX feature 1 feature 2 feature 3  \
# Trade Date
# 2021-09-20  V (Oct 2021)  24.4629  25.709999       NaN       NaN       NaN
# 2021-09-17  V (Oct 2021)  21.9377  20.809999       NaN       NaN       NaN
# 2021-09-16  V (Oct 2021)  20.5556  18.690001       NaN       NaN       NaN
# 2021-09-15  V (Oct 2021)  20.8379  18.180000       NaN       NaN       NaN
# 2021-09-14  U (Sep 2021)  19.7150  19.459999       NaN       NaN       NaN
#
#            feature 4 feature 5 feature 6 feature 7 feature 8 feature 9  \
# Trade Date
# 2021-09-20       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-09-17       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-09-16       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-09-15       NaN       NaN       NaN       NaN       NaN       NaN
# 2021-09-14       NaN       NaN       NaN       NaN       NaN       NaN
#
#            feature 10
# Trade Date
# 2021-09-20        NaN
# 2021-09-17        NaN
# 2021-09-16        NaN
# 2021-09-15        NaN
# 2021-09-14        NaN

# %%
new['feature 1'] = new['Settle']

# %%
# fill the features from 'feature 2' to 'feature 10'
for date in new.index[:] :
    
        for i in range(1, 10) :
            feature_date = pd.to_datetime(date) + pd.DateOffset(months=i)
            try :
                value = new.loc[(new.index == str(feature_date).split()[0]), 'Settle'][0]
                new.at[date, f'feature {i+1}']=value
                
            except :
                pass

# %%
new.drop(['Futures', 'Settle'], axis = 1, inplace = True)
new.head(5)
# Out:
#                   VIX  feature 1 feature 2 feature 3 feature 4 feature 5  \
# Trade Date
# 2021-09-20  25.709999    24.4629       NaN       NaN       NaN       NaN
# 2021-09-17  20.809999    21.9377       NaN       NaN       NaN       NaN
# 2021-09-16  18.690001    20.5556       NaN       NaN       NaN       NaN
# 2021-09-15  18.180000    20.8379       NaN       NaN       NaN       NaN
# 2021-09-14  19.459999    19.7150       NaN       NaN       NaN       NaN
#
#            feature 6 feature 7 feature 8 feature 9 feature 10
# Trade Date
# 2021-09-20       NaN       NaN       NaN       NaN        NaN
# 2021-09-17       NaN       NaN       NaN       NaN        NaN
# 2021-09-16       NaN       NaN       NaN       NaN        NaN
# 2021-09-15       NaN       NaN       NaN       NaN        NaN
# 2021-09-14       NaN       NaN       NaN       NaN        NaN

# %%
new.to_csv('resultat.csv')
